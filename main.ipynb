# %% [markdown]
# cloning project setup to use colab

# %%
# Clone your code into Colab
# !git clone https://github.com/lazylettuce1/MobileNetV2-Compression.git
# Change active directory to your repository root
import os
os.chdir('MobileNetV2-Compression')
# Out:
# fatal: destination path 'MobileNetV2-Compression' already exists and is not an empty directory.

# %%
# Import your module
import torch
from model import MobileNetV2CIFAR

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# %%
m = MobileNetV2CIFAR()
x = torch.randn(2, 3, 32, 32)
print("output shape:", m(x).shape)                # expect [2, 10]
print("final feature map:", m.features(x).shape)  # expect [2, 1280, 4, 4]
print(f"params: {sum(p.numel() for p in m.parameters())/1e6:.2f}M")
# Out:
# output shape: torch.Size([2, 10])
# final feature map: torch.Size([2, 1280, 4, 4])
# params: 2.24M

# %%
from train import TrainConfig, run_training

cfg = TrainConfig(
    epochs=150,
    out_dir="./outputs/20260905_1030_mbnetv2_baseline",
    use_wandb=True,
)
history, model = run_training(cfg)
# Out:
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: You chose 'Create a W&B account'
# wandb: Create an account here: https://wandb.ai/authorize?signup=true&ref=models
# wandb: After creating your account, create a new API key and store it securely.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: lazylettuce1 (lazylettuce1-indian-institute-of-technology-madras) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.28.1
# Run data is saved locally in <code>/content/MobileNetV2-Compression/MobileNetV2-Compression/wandb/run-20260905_050517-nkfv8y8c</code>
# Syncing run <strong><a href='https://wandb.ai/lazylettuce1-indian-institute-of-technology-madras/mobilenetv2-cifar10/runs/nkfv8y8c' target="_blank">splendid-armadillo-1</a></strong> to <a href='https://wandb.ai/lazylettuce1-indian-institute-of-technology-madras/mobilenetv2-cifar10' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/lazylettuce1-indian-institute-of-technology-madras/mobilenetv2-cifar10' target="_blank">https://wandb.ai/lazylettuce1-indian-institute-of-technology-madras/mobilenetv2-cifar10</a>
#  View run at <a href='https://wandb.ai/lazylettuce1-indian-institute-of-technology-madras/mobilenetv2-cifar10/runs/nkfv8y8c' target="_blank">https://wandb.ai/lazylettuce1-indian-institute-of-technology-madras/mobilenetv2-cifar10/runs/nkfv8y8c</a>
# 100%|██████████| 170M/170M [22:03<00:00, 129kB/s]
# /content/MobileNetV2-Compression/MobileNetV2-Compression/train.py:136: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=cfg.amp and device == "cuda")
# /usr/local/lib/python3.13/dist-packages/torch/utils/data/dataloader.py:1118: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# /content/MobileNetV2-Compression/MobileNetV2-Compression/train.py:73: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=scaler.is_enabled()):
# epoch   1/150 | train_loss 1.9298 train_acc 31.24 | test_loss 1.6416 test_acc 47.25 | lr 0.02000 | 1998.0s
# epoch   2/150 | train_loss 1.5552 train_acc 52.05 | test_loss 1.4239 test_acc 58.23 | lr 0.04000 | 2046.5s
# epoch   3/150 | train_loss 1.3137 train_acc 63.72 | test_loss 1.3198 test_acc 65.33 | lr 0.06000 | 2041.1s
# Canceled future for execute_request message before replies were done
# Canceled future for execute_request message before replies were done.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
